# %%
import pandas as pd

# %%
df = pd.read_csv("https://worldmrio.com/unctadgvc/Database_GVC_2018update_rev0323.csv", index_col=0)
df.head()
#DVA is domestic value added
#DVX is indirect value added (reexport to third country)
#FVA is foreign value added
#GVC is GVC participation index
# Out:
#                 DVX1990     DVX1991     DVX1992     DVX1993     DVX1994  \
# Afghanistan    21363.83    20641.58    24619.39    21492.52    20482.61
# Albania        25235.71    13851.77    16495.92    21335.42    22722.49
# Algeria      4221796.00  4086053.00  4416881.00  3938129.00  3849585.00
# Andorra        11783.17    11544.31    14529.66    13505.30    14904.93
# Angola        416258.30   446696.90   597805.10   499129.60   655503.90
#
#                 DVX1995     DVX1996     DVX1997     DVX1998     DVX1999  \
# Afghanistan    28325.23    31116.17    33850.82    36041.83    36677.27
# Albania        31156.03    37355.22    28773.33    34500.27    47577.90
# Algeria      4598457.00  5594659.00  5779090.00  5314842.00  5848078.00
# Andorra        17606.09    20706.12    21623.57    25440.62    26795.05
# Angola        465766.30   606184.20   533241.40   544153.00   603764.80
#
#                  ...          DVA2010     DVA2011     DVA2012     DVA2013  \
# ...

# %%
df_subset = df[['GVC2007', 'GVC2008', 'GVC2009','GVC2010','GVC2011','GVC2012','GVC2013','GVC2014','GVC2015','GVC2016','GVC2017']]
df_subset.head()
# Out:
#                 GVC2007     GVC2008     GVC2009     GVC2010     GVC2011  \
# Afghanistan    126861.3    141408.1    118252.6    146241.4    169978.1
# Albania        423174.5    527565.6    418456.6    691338.8    575218.8
# Algeria      32248880.0  42245650.0  26726960.0  38666680.0  43934240.0
# Andorra        158202.1    168049.1    126871.2    187103.3    190554.6
# Angola        6542127.0   9145319.0   5708851.0   8264022.0  11377260.0
#
#                 GVC2012     GVC2013     GVC2014     GVC2015     GVC2016  \
# Afghanistan    166642.0    182677.3    189157.7    162423.5    158114.9
# Albania        552790.2    578302.1    607947.1    524698.1    559502.0
# Algeria      43102630.0  41840020.0  42266670.0  37725070.0  40141970.0
# Andorra        185082.7    194859.0    206842.3    183127.2    185856.0
# Angola       11050680.0  10808580.0  11471160.0  10262940.0  10058660.0
#
#                 GVC2017
# Afghanistan    167882.1
# Albania        578622.1
# ...

# %%
df.shape
# Out:
# (190, 146)

# %%
df.describe()
# Out:
#             DVX1990       DVX1991       DVX1992       DVX1993       DVX1994  \
# count  1.900000e+02  1.900000e+02  1.900000e+02  1.900000e+02  1.900000e+02
# mean   4.388375e+06  4.641970e+06  5.268749e+06  5.117406e+06  5.807335e+06
# std    1.418177e+07  1.502274e+07  1.707219e+07  1.664983e+07  1.916375e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.776706e+04  1.929395e+04  2.277779e+04  2.154949e+04  2.257991e+04
# 50%    1.439836e+05  1.496961e+05  1.633453e+05  1.662353e+05  1.858565e+05
# 75%    1.734954e+06  1.606516e+06  2.077342e+06  1.952282e+06  2.244949e+06
# max    1.158909e+08  1.221842e+08  1.379714e+08  1.402494e+08  1.677049e+08
#
#             DVX1995       DVX1996       DVX1997       DVX1998       DVX1999  \
# count  1.900000e+02  1.900000e+02  1.900000e+02  1.900000e+02  1.900000e+02
# mean   7.166443e+06  7.716127e+06  7.217008e+06  7.769660e+06  8.029933e+06
# ...

# %%
sorted_by_gross['FVA2017'].head(20).plot(kind="barh")
plt.show()

# %%
sorted_by_gross['DVX2017'].head(20).plot(kind="barh")
plt.show()

# %%
sorted_by_gross['DVA2017'].head(20).plot(kind="barh")
plt.show()

# %%
DVX=df['DVX2017']

# %%
GVC=df['GVC2017']

# %%
FVA=df['FVA2017']

# %%
plt.hist([DVX,FVA,GVC], color=['orange', 'green', 'blue'])
plt.show()

# %%
sorted_by_gross['GVC2017'].head(20).plot(kind="barh")
plt.show()

# %%
#Insitutions from World Governance Indicator
Ins = pd.read_excel('C:/Users/Administrator/Downloads/wgidataset.xlsx',sheet_name='RuleofLaw',skiprows=13,index_col=0)
Ins.head()
# Out:
#                   Unnamed: 1      1996    1996.1  1996.2   1996.3   1996.4  \
# Country/Territory     WBCode  Estimate    StdErr  NumSrc     Rank    Lower
# Aruba                    ABW       NaN       NaN     NaN      NaN      NaN
# Andorra                  ADO   1.15836  0.388865       2  86.4322  63.3166
# Afghanistan              AFG  -1.78808  0.350509       3  1.50754        0
# Angola                   AGO  -1.63047  0.212429       6  3.51759        0
#
#                     1996.5      1998    1998.1  1998.2   ...     2016.2  \
# Country/Territory    Upper  Estimate    StdErr  NumSrc   ...     NumSrc
# Aruba                  NaN       NaN       NaN     NaN   ...          3
# Andorra            96.9849   1.21321  0.365499       2   ...          1
# Afghanistan        12.5628  -1.73714  0.331571       3   ...         11
# Angola             10.0503  -1.70075  0.209898       8   ...         12
#
#                     2016.3   2016.4   2016.5      2017    2017.1  2017.2  \
# ...
